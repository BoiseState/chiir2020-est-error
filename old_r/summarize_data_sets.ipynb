# %% [markdown]
# ## Summarize BookCrossing, ML-100K, ML-20M

# %% [markdown]
# ### Setup

# %%
library(tidyverse)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %%
options(repr.matrix.max.rows=10)
options(repr.plot.height=4.5)

# %%
source("utility.R")

# %% [markdown]
# ### Load data

# %%
bx.ratings = read_csv("data/bx/bx-ratings.csv")
bx.implicit = read_csv("data/bx/bx-implicit.csv") %>%
                    filter(rating != 0)
    
ml.100k = read_tsv("data/ml-100k/u.data", 
                   col_names = c("userId", "movieId", "rating"),
                   col_types = "iid_")
ml.20m = read_csv("data/ml-20m/ratings.csv",
                  col_types = "iid_")
# Out:
# Parsed with column specification:
# cols(
#   userID = col_integer(),
#   bookID = col_integer(),
#   rating = col_double()
# )
# Parsed with column specification:
# cols(
#   userID = col_integer(),
#   bookID = col_integer(),
#   rating = col_double()
# )

# %% [markdown]
# ### Summarize datasets

# %%
summarize_data_sets(BXE=bx.ratings, BXI=bx.implicit, ML100K=ml.100k, ML20M=ml.20m)
# Out:
# Warning message in nuser * nitem:
# “NAs produced by integer overflow”Warning message in nuser * nitem:
# “NAs produced by integer overflow”Warning message in nuser * nitem:
# “NAs produced by integer overflow”
#   DataSet  nuser  nitem    pairs    density
# 1     BXE  77805 166690   431627         NA
# 2     BXI  77803 166687   431534         NA
# 3  ML100K    943   1682   100000 0.06304669
# 4   ML20M 138493  26744 20000263         NA
# Profile Stats
#       BXE               BXI              ML100K           ML20M
#  Min.   :   1.00   Min.   :   1.00   Min.   : 20      Min.   :  20.0
#  1st Qu.:   1.00   1st Qu.:   1.00   1st Qu.: 33      1st Qu.:  35.0
#  Median :   1.00   Median :   1.00   Median : 65      Median :  68.0
#  Mean   :   5.55   Mean   :   5.55   Mean   :106      Mean   : 144.4
#  3rd Qu.:   3.00   3rd Qu.:   3.00   3rd Qu.:148      3rd Qu.: 155.0
#  Max.   :8167.00   Max.   :8140.00   Max.   :737      Max.   :9254.0
# ...
